# %% [markdown]
# # Computational Modelling
#
# I will use this notebook to get started with Computational Modelling for fly motion vision. Let's get started with designing a grating stimulus which moves over time.

# %%
#import necessary modules

import numpy as np
import matplotlib.pyplot as plt

# %%
visual_space_size = 200.0 #total size of visual space
pixel = 1 #pixel size in degree

x = np.arange(0, visual_space_size, pixel) # spatial axis x dimension (200,)

# %%
Amp = 0.5 # amplitude of sine wave (Luminance)
phase = 0 #starting phase for sine wave
lambd = 40.0 # wavelength of sine wave in deg. (lamda is a reserved keyword, so use lambd)
dc = 0.5 # d.c. component in sine wave

pattern = Amp * np.sin((2 * np.pi * (1/lambd) * x) + phase) + dc #sine wave equation y(x,t)=Asin(kx-wt+phi)+d.c (k=2pi/lambd)

# %%
f, ax = plt.subplots()
ax.plot(x,pattern)
ax.set_xlabel("x (deg.)", fontsize = 15)
ax.set_ylabel("Luminance", fontsize = 15)
plt.title("Luminance Pattern over space (sine grating)", fontsize = 20)
plt.show()
